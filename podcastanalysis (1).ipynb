# %%
import pandas as pd
import pandas as pd
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

test=pd.read_csv("C:\\Users\\maddi\\OneDrive\\Desktop\\test.csv")

# %%
test.head(10)
# Out:
#        id         Podcast_Name Episode_Title  Episode_Length_minutes  \
# 0  750000  Educational Nuggets    Episode 73                   78.96
# 1  750001          Sound Waves    Episode 23                   27.87
# 2  750002        Joke Junction    Episode 11                   69.10
# 3  750003        Comedy Corner    Episode 73                  115.39
# 4  750004         Life Lessons    Episode 50                   72.32
# 5  750005        Money Matters    Episode 43                   34.44
# 6  750006      Mystery Matters    Episode 33                  116.09
# 7  750007          Gadget Geek    Episode 24                   54.59
# 8  750008        Home & Living    Episode 87                   92.69
# 9  750009   True Crime Stories    Episode 76                  100.65
#
#         Genre  Host_Popularity_percentage Publication_Day Publication_Time  \
# 0   Education                       38.11        Saturday          Evening
# ...

# %%
test.describe()
# Out:
#                   id  Episode_Length_minutes  Host_Popularity_percentage  \
# count  250000.000000            2.212640e+05               250000.000000
# mean   874999.500000            4.192987e+02                   59.716491
# std     72168.927986            1.668545e+05                   22.880028
# min    750000.000000            2.470000e+00                    2.490000
# 25%    812499.750000            3.578000e+01                   39.250000
# 50%    874999.500000            6.397000e+01                   59.900000
# 75%    937499.250000            9.415000e+01                   79.390000
# max    999999.000000            7.848626e+07                  117.760000
#
#        Guest_Popularity_percentage  Number_of_Ads
# count                201168.000000  250000.000000
# mean                     52.192796       1.355852
# std                      28.445034       4.274399
# min                       0.000000       0.000000
# 25%                      28.320000       0.000000
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id                           250000 non-null  int64
#  1   Podcast_Name                 250000 non-null  object
#  2   Episode_Title                250000 non-null  object
#  3   Episode_Length_minutes       221264 non-null  float64
#  4   Genre                        250000 non-null  object
#  5   Host_Popularity_percentage   250000 non-null  float64
#  6   Publication_Day              250000 non-null  object
#  7   Publication_Time             250000 non-null  object
#  8   Guest_Popularity_percentage  201168 non-null  float64
#  9   Number_of_Ads                250000 non-null  float64
#  10  Episode_Sentiment            250000 non-null  object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 21.0+ MB

# %%
test[["Podcast_Name","Genre"]][0:50:5]
# Out:
#            Podcast_Name       Genre
# 0   Educational Nuggets   Education
# 5         Money Matters    Business
# 10        Finance Focus    Business
# 15           Tech Talks  Technology
# 20          Global News        News
# 25           Sport Spot      Sports
# 30          World Watch        News
# 35    Detective Diaries  True Crime
# 40          Funny Folks      Comedy
# 45            Tune Time       Music

# %%
for rec in test.head(2).iterrows():
    print(rec)
# Out:
# (0, id                                          750000
# Podcast_Name                   Educational Nuggets
# Episode_Title                           Episode 73
# Episode_Length_minutes                       78.96
# Genre                                    Education
# Host_Popularity_percentage                   38.11
# Publication_Day                           Saturday
# Publication_Time                           Evening
# Guest_Popularity_percentage                  53.33
# Number_of_Ads                                  1.0
# Episode_Sentiment                          Neutral
# Name: 0, dtype: object)
# (1, id                                  750001
# Podcast_Name                   Sound Waves
# Episode_Title                   Episode 23
# Episode_Length_minutes               27.87
# Genre                                Music
# Host_Popularity_percentage           71.29
# Publication_Day                     Sunday
# Publication_Time                   Morning
# ...

# %%
test.iloc[:11]
# Out:
#         id         Podcast_Name Episode_Title  Episode_Length_minutes  \
# 0   750000  Educational Nuggets    Episode 73                   78.96
# 1   750001          Sound Waves    Episode 23                   27.87
# 2   750002        Joke Junction    Episode 11                   69.10
# 3   750003        Comedy Corner    Episode 73                  115.39
# 4   750004         Life Lessons    Episode 50                   72.32
# 5   750005        Money Matters    Episode 43                   34.44
# 6   750006      Mystery Matters    Episode 33                  116.09
# 7   750007          Gadget Geek    Episode 24                   54.59
# 8   750008        Home & Living    Episode 87                   92.69
# 9   750009   True Crime Stories    Episode 76                  100.65
# 10  750010        Finance Focus    Episode 31                   23.20
#
#          Genre  Host_Popularity_percentage Publication_Day Publication_Time  \
# ...

# %%
test['Podcast_Name'].unique()
# Out:
# array(['Educational Nuggets', 'Sound Waves', 'Joke Junction',
#        'Comedy Corner', 'Life Lessons', 'Money Matters',
#        'Mystery Matters', 'Gadget Geek', 'Home & Living',
#        'True Crime Stories', 'Finance Focus', 'Innovators',
#        'Crime Chronicles', 'Tech Talks', 'Style Guide', 'World Watch',
#        'Sports Weekly', 'Global News', 'Humor Hub', 'Business Insights',
#        'Sport Spot', 'Digital Digest', 'Fashion Forward',
#        'Sports Central', 'Funny Folks', 'Tech Trends', 'Laugh Line',
#        'Detective Diaries', 'Mind & Body', 'Fitness First', 'Tune Time',
#        'Lifestyle Lounge', 'Business Briefs', 'Wellness Wave',
#        'Market Masters', 'Melody Mix', 'Health Hour', 'Study Sessions',
#        'Daily Digest', 'Healthy Living', 'Learning Lab', 'Music Matters',
#        'Brain Boost', 'Game Day', "Athlete's Arena", 'Criminal Minds',
#        'Current Affairs', 'News Roundup'], dtype=object)

# %%
test.loc[:10,"Podcast_Name"]
# Out:
# 0     Educational Nuggets
# 1             Sound Waves
# 2           Joke Junction
# 3           Comedy Corner
# 4            Life Lessons
# 5           Money Matters
# 6         Mystery Matters
# 7             Gadget Geek
# 8           Home & Living
# 9      True Crime Stories
# 10          Finance Focus
# Name: Podcast_Name, dtype: object

# %%
test.iloc[:10,0:6]
# Out:
#        id         Podcast_Name Episode_Title  Episode_Length_minutes  \
# 0  750000  Educational Nuggets    Episode 73                   78.96
# 1  750001          Sound Waves    Episode 23                   27.87
# 2  750002        Joke Junction    Episode 11                   69.10
# 3  750003        Comedy Corner    Episode 73                  115.39
# 4  750004         Life Lessons    Episode 50                   72.32
# 5  750005        Money Matters    Episode 43                   34.44
# 6  750006      Mystery Matters    Episode 33                  116.09
# 7  750007          Gadget Geek    Episode 24                   54.59
# 8  750008        Home & Living    Episode 87                   92.69
# 9  750009   True Crime Stories    Episode 76                  100.65
#
#         Genre  Host_Popularity_percentage
# 0   Education                       38.11
# 1       Music                       71.29
# 2      Comedy                       67.89
# ...

# %%
test.sort_values("Host_Popularity_percentage",ascending=False)
# Out:
#             id         Podcast_Name Episode_Title  Episode_Length_minutes  \
# 90886   840886        Fitness First    Episode 79                   93.17
# 186742  936742  Educational Nuggets    Episode 45                  116.60
# 88169   838169          World Watch    Episode 67                   39.72
# 143693  893693          World Watch    Episode 78                   10.71
# 180528  930528         News Roundup    Episode 64                  103.11
# ...        ...                  ...           ...                     ...
# 101688  851688      Business Briefs    Episode 63                   89.42
# 121576  871576         Daily Digest    Episode 21                   40.29
# 195165  945165          Global News    Episode 37                    7.99
# 986     750986          Sound Waves    Episode 40                   70.66
# 64298   814298         Daily Digest    Episode 39                   90.87
#
#             Genre  Host_Popularity_percentage Publication_Day  \
# ...

# %%
# to find in which genre people are intrested based on high host_popularity_percentage
test.sort_values(["Host_Popularity_percentage","Genre"])
# Out:
#             id         Podcast_Name Episode_Title  Episode_Length_minutes  \
# 64298   814298         Daily Digest    Episode 39                   90.87
# 986     750986          Sound Waves    Episode 40                   70.66
# 195165  945165          Global News    Episode 37                    7.99
# 101688  851688      Business Briefs    Episode 63                   89.42
# 128411  878411       Healthy Living     Episode 4                   95.18
# ...        ...                  ...           ...                     ...
# 180528  930528         News Roundup    Episode 64                  103.11
# 143693  893693          World Watch    Episode 78                   10.71
# 88169   838169          World Watch    Episode 67                   39.72
# 186742  936742  Educational Nuggets    Episode 45                  116.60
# 90886   840886        Fitness First    Episode 79                   93.17
#
#             Genre  Host_Popularity_percentage Publication_Day  \
# ...

# %%
#adding new_column
test["Best"] = False

# %%
test.drop(["Episode_Sentiment"],axis=1,inplace=False).head()
# Out:
#        id         Podcast_Name Episode_Title  Episode_Length_minutes  \
# 0  750000  Educational Nuggets    Episode 73                   78.96
# 1  750001          Sound Waves    Episode 23                   27.87
# 2  750002        Joke Junction    Episode 11                   69.10
# 3  750003        Comedy Corner    Episode 73                  115.39
# 4  750004         Life Lessons    Episode 50                   72.32
#
#        Genre  Host_Popularity_percentage Publication_Day Publication_Time  \
# 0  Education                       38.11        Saturday          Evening
# 1      Music                       71.29          Sunday          Morning
# 2     Comedy                       67.89          Friday          Evening
# 3     Comedy                       23.40          Sunday          Morning
# 4  Lifestyle                       58.10       Wednesday          Morning
#
#    Guest_Popularity_percentage  Number_of_Ads
# 0                        53.33            1.0
# ...

# %%
#To check wether the sheet is duplicated or not gives boolena result
test.duplicated().head(11)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# dtype: bool

# %%
#to remove duplicates temporarily
test.drop_duplicates()
# Out:
#             id         Podcast_Name Episode_Title  Episode_Length_minutes  \
# 0       750000  Educational Nuggets    Episode 73                   78.96
# 1       750001          Sound Waves    Episode 23                   27.87
# 2       750002        Joke Junction    Episode 11                   69.10
# 3       750003        Comedy Corner    Episode 73                  115.39
# 4       750004         Life Lessons    Episode 50                   72.32
# ...        ...                  ...           ...                     ...
# 249995  999995          Mind & Body   Episode 100                   21.05
# 249996  999996        Joke Junction    Episode 85                   85.50
# 249997  999997        Joke Junction    Episode 63                   12.11
# 249998  999998       Market Masters    Episode 46                  113.46
# 249999  999999          Brain Boost    Episode 46                   78.05
#
#             Genre  Host_Popularity_percentage Publication_Day  \
# ...

# %%
#handling Missing data
test.dropna().head()
# Out:
#        id         Podcast_Name Episode_Title  Episode_Length_minutes  \
# 0  750000  Educational Nuggets    Episode 73                   78.96
# 2  750002        Joke Junction    Episode 11                   69.10
# 3  750003        Comedy Corner    Episode 73                  115.39
# 4  750004         Life Lessons    Episode 50                   72.32
# 6  750006      Mystery Matters    Episode 33                  116.09
#
#         Genre  Host_Popularity_percentage Publication_Day Publication_Time  \
# 0   Education                       38.11        Saturday          Evening
# 2      Comedy                       67.89          Friday          Evening
# 3      Comedy                       23.40          Sunday          Morning
# 4   Lifestyle                       58.10       Wednesday          Morning
# 6  True Crime                       27.57          Friday            Night
#
#    Guest_Popularity_percentage  Number_of_Ads Episode_Sentiment
# ...

# %%
test.fillna(30).head()
# Out:
#        id         Podcast_Name Episode_Title  Episode_Length_minutes  \
# 0  750000  Educational Nuggets    Episode 73                   78.96
# 1  750001          Sound Waves    Episode 23                   27.87
# 2  750002        Joke Junction    Episode 11                   69.10
# 3  750003        Comedy Corner    Episode 73                  115.39
# 4  750004         Life Lessons    Episode 50                   72.32
#
#        Genre  Host_Popularity_percentage Publication_Day Publication_Time  \
# 0  Education                       38.11        Saturday          Evening
# 1      Music                       71.29          Sunday          Morning
# 2     Comedy                       67.89          Friday          Evening
# 3     Comedy                       23.40          Sunday          Morning
# 4  Lifestyle                       58.10       Wednesday          Morning
#
#    Guest_Popularity_percentage  Number_of_Ads Episode_Sentiment
# ...

# %%
#filtering data 
#boolean results are added up and give total count
test.loc[test["Number_of_Ads"]>3]
# Out:
#             id  Podcast_Name Episode_Title  Episode_Length_minutes  \
# 37939   787939  Life Lessons    Episode 94                   89.84
# 178393  928393   Tech Trends    Episode 59                    7.15
#
#              Genre  Host_Popularity_percentage Publication_Day  \
# 37939    Lifestyle                       60.79          Sunday
# 178393  Technology                       71.90          Sunday
#
#        Publication_Time  Guest_Popularity_percentage  Number_of_Ads  \
# 37939         Afternoon                        62.13          89.12
# 178393          Morning                        17.39        2063.00
#
#        Episode_Sentiment
# 37939            Neutral
# 178393          Positive

# %%
test.loc[test["Genre"].str.endswith("ion")]
# Out:
#             id         Podcast_Name Episode_Title  Episode_Length_minutes  \
# 0       750000  Educational Nuggets    Episode 73                   78.96
# 73      750073       Study Sessions    Episode 36                   42.20
# 82      750082         Learning Lab    Episode 95                   26.69
# 91      750091         Learning Lab     Episode 2                  113.39
# 94      750094          Brain Boost    Episode 44                   77.54
# ...        ...                  ...           ...                     ...
# 249962  999962  Educational Nuggets    Episode 91                   49.32
# 249963  999963       Study Sessions    Episode 74                  111.76
# 249988  999988          Brain Boost    Episode 37                   14.23
# 249989  999989  Educational Nuggets     Episode 2                   53.34
# 249999  999999          Brain Boost    Episode 46                   78.05
#
#             Genre  Host_Popularity_percentage Publication_Day  \
# ...

# %%
test.loc[test["Episode_Length_minutes"]>100]
# Out:
#             id        Podcast_Name Episode_Title  Episode_Length_minutes  \
# 3       750003       Comedy Corner    Episode 73                  115.39
# 6       750006     Mystery Matters    Episode 33                  116.09
# 9       750009  True Crime Stories    Episode 76                  100.65
# 22      750022   Business Insights    Episode 78                  102.69
# 41      750041           Tune Time    Episode 55                  115.79
# ...        ...                 ...           ...                     ...
# 249983  999983     Current Affairs    Episode 86                  115.48
# 249985  999985         World Watch    Episode 29                  115.65
# 249991  999991           Tune Time    Episode 86                  103.69
# 249994  999994     Fashion Forward    Episode 36                  119.20
# 249998  999998      Market Masters    Episode 46                  113.46
#
#              Genre  Host_Popularity_percentage Publication_Day  \
# ...

# %%
test.loc[(test.Podcast_Name=="Study Sessions")&(test.Publication_Time=="Morning")]
# Out:
#             id    Podcast_Name Episode_Title  Episode_Length_minutes  \
# 212     750212  Study Sessions    Episode 35                   76.65
# 491     750491  Study Sessions    Episode 29                   47.04
# 530     750530  Study Sessions     Episode 5                   50.99
# 807     750807  Study Sessions    Episode 86                   71.91
# 1037    751037  Study Sessions    Episode 21                     NaN
# ...        ...             ...           ...                     ...
# 248349  998349  Study Sessions    Episode 83                   55.48
# 249115  999115  Study Sessions    Episode 56                   73.02
# 249569  999569  Study Sessions    Episode 72                   39.81
# 249788  999788  Study Sessions    Episode 40                   38.11
# 249918  999918  Study Sessions    Episode 85                  119.76
#
#             Genre  Host_Popularity_percentage Publication_Day  \
# 212     Education                       72.85       Wednesday
# ...

# %%
#to determine the data in particular column
test.loc[test.Podcast_Name.isin(['World Watch','Current Affairs','Tech Talks'])]
# Out:
#             id     Podcast_Name Episode_Title  Episode_Length_minutes  \
# 15      750015       Tech Talks     Episode 4                   87.02
# 17      750017      World Watch    Episode 19                   47.97
# 30      750030      World Watch    Episode 34                   51.81
# 32      750032       Tech Talks    Episode 96                   20.87
# 69      750069       Tech Talks     Episode 1                   59.91
# ...        ...              ...           ...                     ...
# 249958  999958       Tech Talks     Episode 5                   79.24
# 249982  999982       Tech Talks    Episode 48                     NaN
# 249983  999983  Current Affairs    Episode 86                  115.48
# 249985  999985      World Watch    Episode 29                  115.65
# 249986  999986      World Watch    Episode 91                   44.26
#
#              Genre  Host_Popularity_percentage Publication_Day  \
# ...

# %%
#Highlightvalues which are null
test.isnull()
# Out:
#            id  Podcast_Name  Episode_Title  Episode_Length_minutes  Genre  \
# 0       False         False          False                   False  False
# 1       False         False          False                   False  False
# 2       False         False          False                   False  False
# 3       False         False          False                   False  False
# 4       False         False          False                   False  False
# ...       ...           ...            ...                     ...    ...
# 249995  False         False          False                   False  False
# 249996  False         False          False                   False  False
# 249997  False         False          False                   False  False
# 249998  False         False          False                   False  False
# 249999  False         False          False                   False  False
#
#         Host_Popularity_percentage  Publication_Day  Publication_Time  \
# ...

# %%
test.Podcast_Name=="Comedy Corner"
# Out:
# 0         False
# 1         False
# 2         False
# 3          True
# 4         False
#           ...
# 249995    False
# 249996    False
# 249997    False
# 249998    False
# 249999    False
# Name: Podcast_Name, Length: 250000, dtype: bool

# %%
test["Episode_Sentiment"].unique()
# Out:
# array(['Neutral', 'Positive', 'Negative'], dtype=object)

# %%
test.sort_index()
# Out:
#             id         Podcast_Name Episode_Title  Episode_Length_minutes  \
# 0       750000  Educational Nuggets    Episode 73                   78.96
# 1       750001          Sound Waves    Episode 23                   27.87
# 2       750002        Joke Junction    Episode 11                   69.10
# 3       750003        Comedy Corner    Episode 73                  115.39
# 4       750004         Life Lessons    Episode 50                   72.32
# ...        ...                  ...           ...                     ...
# 249995  999995          Mind & Body   Episode 100                   21.05
# 249996  999996        Joke Junction    Episode 85                   85.50
# 249997  999997        Joke Junction    Episode 63                   12.11
# 249998  999998       Market Masters    Episode 46                  113.46
# 249999  999999          Brain Boost    Episode 46                   78.05
#
#             Genre  Host_Popularity_percentage Publication_Day  \
# ...

# %%
import pandas as pd
import pandas as pd
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

test=pd.read_csv("C:\\Users\\maddi\\OneDrive\\Desktop\\test.csv")

test[test["Podcast_Name"] == "Mind & Body"]["Podcast_Name"].value_counts()
# Out:
# Podcast_Name
# Mind & Body    4581
# Name: count, dtype: int64

# %%
#most fequently occuring poadcasts
test["Podcast_Name"].value_counts().idxmax()
# Out:
# 'Tech Talks'

# %%
test.sort_values("Episode_Length_minutes".strip(),ascending=False).head()
# Out:
#             id       Podcast_Name Episode_Title  Episode_Length_minutes  \
# 56597   806597     Market Masters    Episode 23             78486264.00
# 54434   804434    Current Affairs    Episode 36                 7575.00
# 180050  930050         Tech Talks    Episode 23                  120.73
# 72201   822201  Detective Diaries    Episode 81                  120.37
# 108919  858919       Daily Digest    Episode 59                  119.99
#
#              Genre  Host_Popularity_percentage Publication_Day  \
# 56597     Business                       55.45          Monday
# 54434         News                       89.54        Saturday
# 180050  Technology                       50.27          Friday
# 72201   True Crime                       79.40        Thursday
# 108919        News                       24.68        Saturday
#
#        Publication_Time  Guest_Popularity_percentage  Number_of_Ads  \
# 56597           Evening                        48.50            0.0
# ...

# %%
test.groupby('Genre')['Episode_Length_minutes'].count()
# Out:
# Genre
# Business      23594
# Comedy        24219
# Education     14501
# Health        21276
# Lifestyle     24634
# Music         18681
# News          18747
# Sports        25403
# Technology    24947
# True Crime    25262
# Name: Episode_Length_minutes, dtype: int64

# %%
test.describe()
# Out:
#                   id  Episode_Length_minutes  Host_Popularity_percentage  \
# count  250000.000000            2.212640e+05               250000.000000
# mean   874999.500000            4.192987e+02                   59.716491
# std     72168.927986            1.668545e+05                   22.880028
# min    750000.000000            2.470000e+00                    2.490000
# 25%    812499.750000            3.578000e+01                   39.250000
# 50%    874999.500000            6.397000e+01                   59.900000
# 75%    937499.250000            9.415000e+01                   79.390000
# max    999999.000000            7.848626e+07                  117.760000
#
#        Guest_Popularity_percentage  Number_of_Ads
# count                201168.000000  250000.000000
# mean                     52.192796       1.355852
# std                      28.445034       4.274399
# min                       0.000000       0.000000
# 25%                      28.320000       0.000000
# ...

# %%
test.groupby('Genre')['Episode_Length_minutes'].mean()
# Out:
# Genre
# Business      3391.194373
# Comedy          63.551682
# Education       64.835876
# Health          65.365593
# Lifestyle       64.679863
# Music           66.275945
# News            64.140931
# Sports          63.975088
# Technology      64.272335
# True Crime      64.578387
# Name: Episode_Length_minutes, dtype: float64

# %%
test.head(5)
# Out:
#        id         Podcast_Name Episode_Title  Episode_Length_minutes  \
# 0  750000  Educational Nuggets    Episode 73                   78.96
# 1  750001          Sound Waves    Episode 23                   27.87
# 2  750002        Joke Junction    Episode 11                   69.10
# 3  750003        Comedy Corner    Episode 73                  115.39
# 4  750004         Life Lessons    Episode 50                   72.32
#
#        Genre  Host_Popularity_percentage Publication_Day Publication_Time  \
# 0  Education                       38.11        Saturday          Evening
# 1      Music                       71.29          Sunday          Morning
# 2     Comedy                       67.89          Friday          Evening
# 3     Comedy                       23.40          Sunday          Morning
# 4  Lifestyle                       58.10       Wednesday          Morning
#
#    Guest_Popularity_percentage  Number_of_Ads Episode_Sentiment
# ...

# %%
test[test['Podcast_Name']=='Tech Talks']['Episode_Length_minutes'].mean()
# Out:
# 64.64059308051279

# %%
test['Podcast_Name'].value_counts().idxmin()
# Out:
# 'News Roundup'

# %%
test['Podcast_Name'].value_counts().sort_values()
# Out:
# Podcast_Name
# News Roundup           3138
# Health Hour            3762
# Brain Boost            3944
# Educational Nuggets    3963
# Healthy Living         4097
# Learning Lab           4202
# Music Matters          4272
# Market Masters         4280
# Innovators             4295
# Study Sessions         4336
# Money Matters          4429
# Daily Digest           4436
# Current Affairs        4489
# World Watch            4556
# Mind & Body            4581
# Global News            4625
# Sound Waves            4689
# Life Lessons           4823
# Sport Spot             4844
# Gadget Geek            4849
# Laugh Line             4906
# Home & Living          4933
# Wellness Wave          4948
# Joke Junction          5039
# Digital Digest         5246
# Comedy Corner          5258
# Mystery Matters        5268
# True Crime Stories     5417
# Sports Central         5424
# Humor Hub              5476
# Athlete's Arena        5662
# Business Briefs        5685
# ...

# %%
test['Publication_Day'].value_counts().idxmax()
# Out:
# 'Sunday'

# %%
test[test['Podcast_Name']=='Tech Talks']['Publication_Day'].value_counts().idxmax()
# Out:
# 'Thursday'
